# %%
import numpy as np

import pandas as pd

from sklearn.metrics import root_mean_squared_log_error
from sklearn.model_selection import KFold
from insurance.common import PREP_DATA_PATH
from insurance.data_pipeline import get_feat_columns, make_xgboost_pipeline
from autogluon.tabular import TabularDataset, TabularPredictor

# %%
prep_data_path = PREP_DATA_PATH / "prepared_data.feather"
target_column = "Premium Amount"

df = pd.read_feather(prep_data_path)

feat_cols = get_feat_columns()
feat_names = feat_cols.names


df[target_column] = np.log1p(df[target_column])

# Fit the pipeline
data_pipeline = make_xgboost_pipeline()
X_train = data_pipeline.fit_transform(df)
for col in feat_cols.categorical:
    X_train[col] = X_train[col].astype("category")
display(X_train.head())
display(X_train.columns)
# Out:
#          year  month  day  dayofweek   Age  Gender  Annual Income  \
# 372605   2020      2   10          0  52.0  Female         5538.0
# 551204   2020     10   16          4  60.0  Female        39711.0
# 240320   2021      1    2          5  58.0  Female         2364.0
# 1047361  2022      5   11          2  39.0    Male         9094.0
# 555362   2020      7   28          1  47.0    Male        43189.0
#
#         Marital Status  Number of Dependents Education Level  ...  \
# 372605         Married                   NaN        Master's  ...
# 551204         Married                   4.0      Bachelor's  ...
# 240320         Married                   2.0      Bachelor's  ...
# 1047361       Divorced                   0.0      Bachelor's  ...
# 555362        Divorced                   NaN             PhD  ...
#
#            Policy Type  Previous Claims Vehicle Age Credit Score  \
# 372605           Basic              0.0        18.0        497.0
# 551204   Comprehensive              0.0         3.0        340.0
# 240320   Comprehensive              2.0        19.0          NaN
# 1047361          Basic              1.0        17.0        761.0
# 555362   Comprehensive              1.0         4.0        319.0
#
#          Insurance Duration  Customer Feedback  Smoking Status  \
# 372605                  3.0            Average              No
# 551204                  3.0               Poor              No
# 240320                  7.0               Poor              No
# 1047361                 5.0               Poor             Yes
# 555362                  4.0               Poor             Yes
#
#          Exercise Frequency Property Type Premium Amount
# 372605               Weekly     Apartment       7.916807
# 551204               Weekly     Apartment       7.206377
# 240320              Monthly         House       7.694848
# 1047361              Rarely         Condo       6.529419
# 555362               Weekly     Apartment       7.447168
#
# [5 rows x 23 columns]
# Index(['year', 'month', 'day', 'dayofweek', 'Age', 'Gender', 'Annual Income',
#        'Marital Status', 'Number of Dependents', 'Education Level',
#        'Occupation', 'Health Score', 'Location', 'Policy Type',
#        'Previous Claims', 'Vehicle Age', 'Credit Score', 'Insurance Duration',
#        'Customer Feedback', 'Smoking Status', 'Exercise Frequency',
#        'Property Type', 'Premium Amount'],
#       dtype='object')

# %%
predictor = TabularPredictor(
    label=target_column, problem_type="regression", eval_metric="root_mean_squared_error"
)

predictor.fit(
    X_train, time_limit=3600 * 6, presets="best", excluded_model_types=["KNN"], num_stack_levels=4
)
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20241223_135741"
# Preset alias specified: 'best' maps to 'best_quality'.
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.2
# Python Version:     3.11.2
# Operating System:   Linux
# Platform Machine:   x86_64
# Platform Version:   #1 SMP PREEMPT_DYNAMIC Debian 6.1.115-1 (2024-11-01)
# CPU Count:          12
# Memory Avail:       10.85 GB / 15.46 GB (70.2%)
# Disk Space Avail:   713.62 GB / 871.45 GB (81.9%)
# ===================================================
# Presets specified: ['best']
# Setting dynamic_stacking from 'auto' to True. Reason: Enable dynamic_stacking when use_bag_holdout is disabled. (use_bag_holdout=False)
# Stack configuration (auto_stack=True): num_stack_levels=4, num_bag_folds=8, num_bag_sets=1
# DyStack is enabled (dynamic_stacking=True). AutoGluon will try to determine whether the input data is affected by stacked overfitting and enable or disable stacking as a consequence.
# 	This is used to identify the optimal `num_stack_levels` value. Copies of AutoGluon will be fit on subsets of the data. Then holdout validation data is used to detect stacked overfitting.
# 	Running DyStack for up to 5400s of the 21600s of remaining time (25%).
# 		Context path: "/mnt/data/Projects/insurance/notebooks/AutogluonModels/ag-20241223_135741/ds_sub_fit/sub_fit_ho"
# Leaderboard on holdout data (DyStack):
#                      model  score_holdout  score_val              eval_metric  pred_time_test  pred_time_val     fit_time  pred_time_test_marginal  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0      WeightedEnsemble_L6      -1.047964  -1.044281  root_mean_squared_error       41.301594     269.453885  4574.519996                 0.004111                0.007787           1.758256            6       True         26
# 1          LightGBM_BAG_L2      -1.047970  -1.044432  root_mean_squared_error       21.843592     186.472570  1335.318223                 0.542257                3.189361          21.188858            2       True          7
# 2      WeightedEnsemble_L3      -1.047984  -1.044346  root_mean_squared_error       28.414484     217.370863  2235.014386                 0.019180                0.008422           0.435168            3       True         10
# 3          LightGBM_BAG_L4      -1.047993  -1.044489  root_mean_squared_error       34.791260     245.339946  3645.641495                 0.428702                2.022876          18.689235            4       True         17
# 4          LightGBM_BAG_L5      -1.048007  -1.044569  root_mean_squared_error       41.297483     269.446099  4572.761740                 0.388056                1.818230          15.550029            5       True         23
# 5          LightGBM_BAG_L3      -1.048023  -1.044399  root_mean_squared_error       29.013033     219.384573  2542.897824                 0.367667                1.854769          15.209540            3       True         12
# 6      WeightedEnsemble_L5      -1.048035  -1.044446  root_mean_squared_error       38.836205     265.123225  4296.774010                 0.002371                0.007677           0.496255            5       True         21
# 7      WeightedEnsemble_L4      -1.048062  -1.044360  root_mean_squared_error       34.134907     242.969961  3376.908158                 0.002263                0.007926           0.431329            4       True         15
# 8        LightGBMXT_BAG_L5      -1.048172  -1.044709  root_mean_squared_error       41.524347     271.569418  4582.751472                 0.614919                3.941549          25.539760            5       True         22
# 9        LightGBMXT_BAG_L3      -1.048357  -1.044737  root_mean_squared_error       29.637886     223.704036  2560.591593                 0.992521                6.174232          32.903309            3       True         11
# 10       LightGBMXT_BAG_L4      -1.048438  -1.044828  root_mean_squared_error       35.144120     249.315574  3658.137269                 0.781562                5.998505          31.185009            4       True         16
# 11       LightGBMXT_BAG_L2      -1.048488  -1.044931  root_mean_squared_error       22.584733     192.514498  1355.797612                 1.283398                9.231289          41.668247            2       True          6
# 12     WeightedEnsemble_L2      -1.048509  -1.044941  root_mean_squared_error        7.080926      37.320882   609.080397                 0.002056                0.008264           0.443348            2       True          5
# 13         LightGBM_BAG_L1      -1.049304  -1.045909  root_mean_squared_error        2.165719      17.101829    53.426870                 2.165719               17.101829          53.426870            1       True          2
# 14  RandomForestMSE_BAG_L2      -1.049362  -1.046474  root_mean_squared_error       26.569649     204.941791  2171.722113                 5.268314               21.658582         857.592748            2       True          8
# 15  RandomForestMSE_BAG_L4      -1.049407  -1.047456  root_mean_squared_error       37.623570     257.094167  4246.403511                 3.261012               13.777098         619.451251            4       True         18
# 16  RandomForestMSE_BAG_L3      -1.049669  -1.047024  root_mean_squared_error       32.772457     234.933034  3328.363980                 4.127091               17.403230         800.675696            3       True         13
# 17  RandomForestMSE_BAG_L1      -1.049978  -1.046952  root_mean_squared_error        4.913151      20.210789   555.210179                 4.913151               20.210789         555.210179            1       True          3
# 18  RandomForestMSE_BAG_L5      -1.050439  -1.050301  root_mean_squared_error       41.791837     274.331379  4871.064531                 0.882410                6.703510         313.852819            5       True         24
# 19       LightGBMXT_BAG_L1      -1.052708  -1.049584  root_mean_squared_error       13.797634     143.612812   281.111481                13.797634              143.612812         281.111481            1       True          1
# 20         CatBoost_BAG_L4      -1.057776  -1.062837  root_mean_squared_error       34.597103     243.507764  3871.445959                 0.234545                0.190695         244.493699            4       True         19
# 21         CatBoost_BAG_L2      -1.058300  -1.062844  root_mean_squared_error       21.551398     183.450572  1607.238431                 0.250062                0.167363         293.109066            2       True          9
# 22         CatBoost_BAG_L5      -1.061175  -1.065963  root_mean_squared_error       40.986483     267.867730  4669.731665                 0.077055                0.239861         112.519953            5       True         25
# 23         CatBoost_BAG_L3      -1.063960  -1.065499  root_mean_squared_error       28.875279     217.884839  2778.163715                 0.229914                0.355035         250.475431            3       True         14
# 24         CatBoost_BAG_L1      -1.069543  -1.073597  root_mean_squared_error        0.424832       2.357779   424.380834                 0.424832                2.357779         424.380834            1       True          4
# 25          XGBoost_BAG_L4      -1.071378  -1.067325  root_mean_squared_error       36.203607     245.638695  3643.392518                 1.841048                2.321626          16.440258            4       True         20
# 	4	 = Optimal   num_stack_levels (Stacked Overfitting Occurred: False)
# 	5453s	 = DyStack   runtime |	16147s	 = Remaining runtime
# Starting main fit with num_stack_levels=4.
# 	For future fit calls on this dataset, you can skip DyStack to save time: `predictor.fit(..., dynamic_stacking=False, num_stack_levels=4)`
# Beginning AutoGluon training ... Time limit = 16147s
# AutoGluon will save models to "/mnt/data/Projects/insurance/notebooks/AutogluonModels/ag-20241223_135741"
# Train Data Rows:    1200000
# Train Data Columns: 22
# Label Column:       Premium Amount
# Problem Type:       regression
# Preprocessing data ...
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    9887.16 MB
# 	Train Data (Original)  Memory Usage: 103.00 MB (1.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 2 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting CategoryFeatureGenerator...
# 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('category', []) : 10 | ['Gender', 'Marital Status', 'Education Level', 'Occupation', 'Location', ...]
# 		('float', [])    :  8 | ['Age', 'Annual Income', 'Number of Dependents', 'Health Score', 'Previous Claims', ...]
# 		('int', [])      :  4 | ['year', 'month', 'day', 'dayofweek']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('category', [])  : 8 | ['Marital Status', 'Education Level', 'Occupation', 'Location', 'Policy Type', ...]
# 		('float', [])     : 8 | ['Age', 'Annual Income', 'Number of Dependents', 'Health Score', 'Previous Claims', ...]
# 		('int', [])       : 4 | ['year', 'month', 'day', 'dayofweek']
# 		('int', ['bool']) : 2 | ['Gender', 'Smoking Status']
# 	1.2s = Fit runtime
# 	22 features in original data used to generate 22 features in processed data.
# 	Train Data (Processed) Memory Usage: 103.00 MB (1.0% of available memory)
# Data preprocessing and feature engineering runtime = 1.3s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'root_mean_squared_error'
# 	This metric's sign has been flipped to adhere to being higher_is_better. The metric score can be multiplied by -1 to get the metric value.
# 	To change this, specify the eval_metric parameter of Predictor()
# Large model count detected (112 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, {'learning_rate': 0.03, 'num_leaves': 128, 'feature_fraction': 0.9, 'min_data_in_leaf': 3, 'ag_args': {'name_suffix': 'Large', 'priority': 0, 'hyperparameter_tune_kwargs': None}}],
# 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# AutoGluon will fit 5 stack levels (L1 to L5) ...
# Excluded models: ['KNN'] (Specified by `excluded_model_types`)
# Fitting 106 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 4304.39s of the 16145.48s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=6.76%)
# 	-1.0498	 = Validation score   (-root_mean_squared_error)
# 	310.9s	 = Training   runtime
# 	159.59s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 3971.67s of the 15812.77s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=6.83%)
# 	-1.0462	 = Validation score   (-root_mean_squared_error)
# 	67.23s	 = Training   runtime
# 	24.2s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L1 ... Training model for up to 3897.95s of the 15739.05s of remaining time.
# 	-1.0471	 = Validation score   (-root_mean_squared_error)
# 	629.37s	 = Training   runtime
# 	21.49s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 3246.44s of the 15087.54s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=7.08%)
# 	-1.0708	 = Validation score   (-root_mean_squared_error)
# 	2611.31s	 = Training   runtime
# 	0.31s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L1 ... Training model for up to 633.71s of the 12474.80s of remaining time.
# 	-1.0476	 = Validation score   (-root_mean_squared_error)
# 	342.29s	 = Training   runtime
# 	19.11s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 271.66s of the 12112.76s of remaining time.
# 	Memory not enough to fit 8 folds in parallel. Will train 4 folds in parallel instead (Estimated 13.99% memory usage per fold, 55.95%/80.00% total).
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=3, gpus=0, memory=13.99%)
# 	-1.0646	 = Validation score   (-root_mean_squared_error)
# 	186.89s	 = Training   runtime
# 	7.53s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 83.07s of the 11924.17s of remaining time.
# 	Memory not enough to fit 8 folds in parallel. Will train 4 folds in parallel instead (Estimated 12.03% memory usage per fold, 48.11%/80.00% total).
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=3, gpus=0, memory=12.03%)
# 	-1.046	 = Validation score   (-root_mean_squared_error)
# 	68.55s	 = Training   runtime
# 	4.73s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 12.48s of the 11853.58s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=8.33%)
# 	Time limit exceeded... Skipping NeuralNetTorch_BAG_L1.
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 430.44s of the 11825.64s of remaining time.
# 	Ensemble Weights: {'RandomForestMSE_BAG_L1': 0.364, 'XGBoost_BAG_L1': 0.364, 'LightGBM_BAG_L1': 0.273}
# 	-1.0451	 = Validation score   (-root_mean_squared_error)
# 	1.28s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Excluded models: ['KNN'] (Specified by `excluded_model_types`)
# Fitting 106 L2 models, fit_strategy="sequential" ...
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 3940.44s of the 11824.21s of remaining time.
# 	Memory not enough to fit 8 folds in parallel. Will train 2 folds in parallel instead (Estimated 22.20% memory usage per fold, 44.40%/80.00% total).
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=6, gpus=0, memory=22.20%)
# 2024-12-23 11:40:40,232	ERROR worker.py:422 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::_ray_fit() (pid=218387, ip=192.168.1.84)
#   File "/mnt/data/Projects/insurance/.venv/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 413, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
#   File "/mnt/data/Projects/insurance/.venv/lib/python3.11/site-packages/autogluon/core/models/abstract/abstract_model.py", line 925, in fit
#     out = self._fit(**kwargs)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/mnt/data/Projects/insurance/.venv/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 224, in _fit
#     raise TimeLimitExceeded
# autogluon.core.utils.exceptions.TimeLimitExceeded
# 2024-12-23 11:40:40,262	ERROR worker.py:422 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::_ray_fit() (pid=218322, ip=192.168.1.84)
#   File "/mnt/data/Projects/insurance/.venv/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 413, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
#   File "/mnt/data/Projects/insurance/.venv/lib/python3.11/site-packages/autogluon/core/models/abstract/abstract_model.py", line 925, in fit
#     out = self._fit(**kwargs)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/mnt/data/Projects/insurance/.venv/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 224, in _fit
#     raise TimeLimitExceeded
# autogluon.core.utils.exceptions.TimeLimitExceeded
# 2024-12-23 11:40:40,263	ERROR worker.py:422 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::_ray_fit() (pid=218386, ip=192.168.1.84)
#   File "/mnt/data/Projects/insurance/.venv/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 413, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
#   File "/mnt/data/Projects/insurance/.venv/lib/python3.11/site-packages/autogluon/core/models/abstract/abstract_model.py", line 925, in fit
#     out = self._fit(**kwargs)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/mnt/data/Projects/insurance/.venv/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 224, in _fit
#     raise TimeLimitExceeded
# autogluon.core.utils.exceptions.TimeLimitExceeded
# 2024-12-23 11:40:40,263	ERROR worker.py:422 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::_ray_fit() (pid=218388, ip=192.168.1.84)
#   File "/mnt/data/Projects/insurance/.venv/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 413, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
#   File "/mnt/data/Projects/insurance/.venv/lib/python3.11/site-packages/autogluon/core/models/abstract/abstract_model.py", line 925, in fit
#     out = self._fit(**kwargs)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/mnt/data/Projects/insurance/.venv/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 224, in _fit
#     raise TimeLimitExceeded
# autogluon.core.utils.exceptions.TimeLimitExceeded
# 2024-12-23 11:40:40,264	ERROR worker.py:422 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::_ray_fit() (pid=218309, ip=192.168.1.84)
#   File "/mnt/data/Projects/insurance/.venv/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 413, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
#   File "/mnt/data/Projects/insurance/.venv/lib/python3.11/site-packages/autogluon/core/models/abstract/abstract_model.py", line 925, in fit
#     out = self._fit(**kwargs)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/mnt/data/Projects/insurance/.venv/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 224, in _fit
#     raise TimeLimitExceeded
# autogluon.core.utils.exceptions.TimeLimitExceeded
# 2024-12-23 11:40:40,264	ERROR worker.py:422 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::_ray_fit() (pid=218385, ip=192.168.1.84)
#   File "/mnt/data/Projects/insurance/.venv/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 413, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
#   File "/mnt/data/Projects/insurance/.venv/lib/python3.11/site-packages/autogluon/core/models/abstract/abstract_model.py", line 925, in fit
#     out = self._fit(**kwargs)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/mnt/data/Projects/insurance/.venv/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 224, in _fit
#     raise TimeLimitExceeded
# autogluon.core.utils.exceptions.TimeLimitExceeded
# 2024-12-23 11:40:40,265	ERROR worker.py:422 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::_ray_fit() (pid=218347, ip=192.168.1.84)
#   File "/mnt/data/Projects/insurance/.venv/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 413, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
#   File "/mnt/data/Projects/insurance/.venv/lib/python3.11/site-packages/autogluon/core/models/abstract/abstract_model.py", line 925, in fit
#     out = self._fit(**kwargs)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/mnt/data/Projects/insurance/.venv/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 224, in _fit
#     raise TimeLimitExceeded
# autogluon.core.utils.exceptions.TimeLimitExceeded
# 	-1.0448	 = Validation score   (-root_mean_squared_error)
# 	34.51s	 = Training   runtime
# 	1.16s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 3897.84s of the 11781.61s of remaining time.
# 	Memory not enough to fit 8 folds in parallel. Will train 4 folds in parallel instead (Estimated 10.89% memory usage per fold, 43.58%/80.00% total).
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=3, gpus=0, memory=10.89%)
# 	-1.0445	 = Validation score   (-root_mean_squared_error)
# 	22.85s	 = Training   runtime
# 	1.48s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L2 ... Training model for up to 3873.09s of the 11756.86s of remaining time.
# 	-1.0465	 = Validation score   (-root_mean_squared_error)
# 	1328.6s	 = Training   runtime
# 	24.58s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 2519.06s of the 10402.83s of remaining time.
# 	Memory not enough to fit 8 folds in parallel. Will train 4 folds in parallel instead (Estimated 11.83% memory usage per fold, 47.32%/80.00% total).
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=3, gpus=0, memory=11.83%)
# 	-1.0606	 = Validation score   (-root_mean_squared_error)
# 	648.82s	 = Training   runtime
# 	0.28s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L2 ... Training model for up to 1868.44s of the 9752.21s of remaining time.
# 	-1.0455	 = Validation score   (-root_mean_squared_error)
# 	490.81s	 = Training   runtime
# 	19.54s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 1357.21s of the 9240.98s of remaining time.
# 	Memory not enough to fit 8 folds in parallel. Will train 2 folds in parallel instead (Estimated 20.46% memory usage per fold, 40.93%/80.00% total).
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=6, gpus=0, memory=20.46%)
# 	-1.0448	 = Validation score   (-root_mean_squared_error)
# 	794.63s	 = Training   runtime
# 	7.69s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ... Training model for up to 560.27s of the 8444.04s of remaining time.
# 	Memory not enough to fit 8 folds in parallel. Will train 4 folds in parallel instead (Estimated 16.47% memory usage per fold, 65.89%/80.00% total).
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=3, gpus=0, memory=16.47%)
# 	-1.0445	 = Validation score   (-root_mean_squared_error)
# 	59.47s	 = Training   runtime
# 	3.61s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 498.67s of the 8382.44s of remaining time.
# 	Memory not enough to fit 8 folds in parallel. Will train 4 folds in parallel instead (Estimated 11.74% memory usage per fold, 46.98%/80.00% total).
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=3, gpus=0, memory=11.74%)
# 	-1.0689	 = Validation score   (-root_mean_squared_error)
# 	398.45s	 = Training   runtime
# 	6.61s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L2 ... Training model for up to 97.98s of the 7981.75s of remaining time.
# 	Memory not enough to fit 8 folds in parallel. Will train 4 folds in parallel instead (Estimated 12.39% memory usage per fold, 49.57%/80.00% total).
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=3, gpus=0, memory=12.39%)
# 	-1.0447	 = Validation score   (-root_mean_squared_error)
# 	32.05s	 = Training   runtime
# 	2.24s	 = Validation runtime
# Fitting model: CatBoost_r177_BAG_L2 ... Training model for up to 64.02s of the 7947.79s of remaining time.
# 	Memory not enough to fit 8 folds in parallel. Will train 4 folds in parallel instead (Estimated 12.36% memory usage per fold, 49.44%/80.00% total).
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=3, gpus=0, memory=12.36%)
# 	-1.0447	 = Validation score   (-root_mean_squared_error)
# 	51.59s	 = Training   runtime
# 	0.33s	 = Validation runtime
# Fitting model: NeuralNetTorch_r79_BAG_L2 ... Training model for up to 10.69s of the 7894.46s of remaining time.
# 	Memory not enough to fit 8 folds in parallel. Will train 4 folds in parallel instead (Estimated 11.71% memory usage per fold, 46.83%/80.00% total).
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=3, gpus=0, memory=11.71%)
# 	Time limit exceeded... Skipping NeuralNetTorch_r79_BAG_L2.
# Fitting model: WeightedEnsemble_L3 ... Training model for up to 394.04s of the 7878.68s of remaining time.
# 	Ensemble Weights: {'LightGBM_BAG_L2': 0.4, 'XGBoost_BAG_L2': 0.3, 'RandomForestMSE_BAG_L2': 0.1, 'ExtraTreesMSE_BAG_L2': 0.1, 'NeuralNetFastAI_BAG_L2': 0.1}
# 	-1.0444	 = Validation score   (-root_mean_squared_error)
# 	1.33s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Excluded models: ['KNN'] (Specified by `excluded_model_types`)
# Fitting 106 L3 models, fit_strategy="sequential" ...
# Fitting model: LightGBMXT_BAG_L3 ... Training model for up to 3500.14s of the 7877.18s of remaining time.
# 	Memory not enough to fit 8 folds in parallel. Will train 4 folds in parallel instead (Estimated 13.80% memory usage per fold, 55.20%/80.00% total).
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=3, gpus=0, memory=13.80%)
# 2024-12-23 12:46:27,909	ERROR worker.py:422 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2024-12-23 12:46:27,910	ERROR worker.py:422 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::_ray_fit() (pid=232850, ip=192.168.1.84)
#   File "/mnt/data/Projects/insurance/.venv/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 413, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
#   File "/mnt/data/Projects/insurance/.venv/lib/python3.11/site-packages/autogluon/core/models/abstract/abstract_model.py", line 925, in fit
#     out = self._fit(**kwargs)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/mnt/data/Projects/insurance/.venv/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 224, in _fit
#     raise TimeLimitExceeded
# autogluon.core.utils.exceptions.TimeLimitExceeded
# 2024-12-23 12:46:27,910	ERROR worker.py:422 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 	-1.0445	 = Validation score   (-root_mean_squared_error)
# 	26.43s	 = Training   runtime
# 	1.92s	 = Validation runtime
# Fitting model: LightGBM_BAG_L3 ... Training model for up to 3471.98s of the 7849.03s of remaining time.
# 	Memory not enough to fit 8 folds in parallel. Will train 4 folds in parallel instead (Estimated 13.64% memory usage per fold, 54.55%/80.00% total).
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=3, gpus=0, memory=13.64%)
# 	-1.0444	 = Validation score   (-root_mean_squared_error)
# 	21.08s	 = Training   runtime
# 	1.19s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L3 ... Training model for up to 3448.95s of the 7826.00s of remaining time.
# 	-1.0466	 = Validation score   (-root_mean_squared_error)
# 	1955.3s	 = Training   runtime
# 	26.5s	 = Validation runtime
# Fitting model: CatBoost_BAG_L3 ... Training model for up to 1466.18s of the 5843.23s of remaining time.
# 	Memory not enough to fit 8 folds in parallel. Will train 4 folds in parallel instead (Estimated 14.69% memory usage per fold, 58.78%/80.00% total).
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=3, gpus=0, memory=14.69%)
# 	-1.0763	 = Validation score   (-root_mean_squared_error)
# 	426.33s	 = Training   runtime
# 	0.62s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L3 ... Training model for up to 1038.00s of the 5415.05s of remaining time.
# 	-1.0455	 = Validation score   (-root_mean_squared_error)
# 	469.35s	 = Training   runtime
# 	19.69s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L3 ... Training model for up to 548.00s of the 4925.05s of remaining time.
# 	Memory not enough to fit 8 folds in parallel. Will train 2 folds in parallel instead (Estimated 25.16% memory usage per fold, 50.31%/80.00% total).
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=6, gpus=0, memory=25.16%)
# 	-1.0444	 = Validation score   (-root_mean_squared_error)
# 	368.2s	 = Training   runtime
# 	5.88s	 = Validation runtime
# Fitting model: XGBoost_BAG_L3 ... Training model for up to 177.55s of the 4554.59s of remaining time.
# 	Memory not enough to fit 8 folds in parallel. Will train 4 folds in parallel instead (Estimated 19.05% memory usage per fold, 76.21%/80.00% total).
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=3, gpus=0, memory=19.05%)
# 	-1.0445	 = Validation score   (-root_mean_squared_error)
# 	62.32s	 = Training   runtime
# 	3.27s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L3 ... Training model for up to 113.03s of the 4490.07s of remaining time.
# 	Memory not enough to fit 8 folds in parallel. Will train 4 folds in parallel instead (Estimated 14.05% memory usage per fold, 56.21%/80.00% total).
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=3, gpus=0, memory=14.05%)
# 	-1.0784	 = Validation score   (-root_mean_squared_error)
# 	92.01s	 = Training   runtime
# 	7.19s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L3 ... Training model for up to 18.05s of the 4395.10s of remaining time.
# 	Memory not enough to fit 8 folds in parallel. Will train 4 folds in parallel instead (Estimated 14.70% memory usage per fold, 58.78%/80.00% total).
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=3, gpus=0, memory=14.70%)
# 	-1.0473	 = Validation score   (-root_mean_squared_error)
# 	16.88s	 = Training   runtime
# 	0.98s	 = Validation runtime
# Fitting model: WeightedEnsemble_L4 ... Training model for up to 360.00s of the 4375.61s of remaining time.
# 	Ensemble Weights: {'LightGBMXT_BAG_L3': 0.227, 'LightGBM_BAG_L3': 0.227, 'NeuralNetFastAI_BAG_L3': 0.227, 'XGBoost_BAG_L3': 0.227, 'RandomForestMSE_BAG_L3': 0.045, 'ExtraTreesMSE_BAG_L3': 0.045}
# 	-1.0443	 = Validation score   (-root_mean_squared_error)
# 	1.05s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Excluded models: ['KNN'] (Specified by `excluded_model_types`)
# Fitting 106 L4 models, fit_strategy="sequential" ...
# Fitting model: LightGBMXT_BAG_L4 ... Training model for up to 2915.60s of the 4374.39s of remaining time.
# 	Memory not enough to fit 8 folds in parallel. Will train 4 folds in parallel instead (Estimated 13.93% memory usage per fold, 55.70%/80.00% total).
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=3, gpus=0, memory=13.93%)
# 	-1.0445	 = Validation score   (-root_mean_squared_error)
# 	23.76s	 = Training   runtime
# 	1.52s	 = Validation runtime
# Fitting model: LightGBM_BAG_L4 ... Training model for up to 2889.98s of the 4348.77s of remaining time.
# 	Memory not enough to fit 8 folds in parallel. Will train 4 folds in parallel instead (Estimated 13.95% memory usage per fold, 55.81%/80.00% total).
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=3, gpus=0, memory=13.95%)
# 	-1.0444	 = Validation score   (-root_mean_squared_error)
# 	20.32s	 = Training   runtime
# 	1.15s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L4 ... Training model for up to 2866.99s of the 4325.78s of remaining time.
# 	-1.0466	 = Validation score   (-root_mean_squared_error)
# 	1922.55s	 = Training   runtime
# 	25.79s	 = Validation runtime
# Fitting model: CatBoost_BAG_L4 ... Training model for up to 917.78s of the 2376.57s of remaining time.
# 	Memory not enough to fit 8 folds in parallel. Will train 4 folds in parallel instead (Estimated 17.00% memory usage per fold, 68.01%/80.00% total).
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=3, gpus=0, memory=17.00%)
# 	-1.0707	 = Validation score   (-root_mean_squared_error)
# 	167.26s	 = Training   runtime
# 	0.4s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L4 ... Training model for up to 748.74s of the 2207.53s of remaining time.
# 	-1.0456	 = Validation score   (-root_mean_squared_error)
# 	480.45s	 = Training   runtime
# 	18.36s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L4 ... Training model for up to 249.05s of the 1707.84s of remaining time.
# 	Memory not enough to fit 8 folds in parallel. Will train 2 folds in parallel instead (Estimated 31.09% memory usage per fold, 62.17%/80.00% total).
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=6, gpus=0, memory=31.09%)
# 	-1.0444	 = Validation score   (-root_mean_squared_error)
# 	176.77s	 = Training   runtime
# 	6.43s	 = Validation runtime
# Fitting model: XGBoost_BAG_L4 ... Training model for up to 68.82s of the 1527.61s of remaining time.
# 	Memory not enough to fit 8 folds in parallel. Will train 2 folds in parallel instead (Estimated 23.70% memory usage per fold, 47.40%/80.00% total).
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=6, gpus=0, memory=23.70%)
# 	-1.0445	 = Validation score   (-root_mean_squared_error)
# 	59.1s	 = Training   runtime
# 	2.92s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L4 ... Training model for up to 7.58s of the 1466.37s of remaining time.
# 	Memory not enough to fit 8 folds in parallel. Will train 4 folds in parallel instead (Estimated 17.16% memory usage per fold, 68.65%/80.00% total).
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=3, gpus=0, memory=17.16%)
# 	Time limit exceeded... Skipping NeuralNetTorch_BAG_L4.
# Fitting model: WeightedEnsemble_L5 ... Training model for up to 360.00s of the 1445.17s of remaining time.
# 	Ensemble Weights: {'LightGBM_BAG_L4': 0.333, 'LightGBMXT_BAG_L4': 0.222, 'NeuralNetFastAI_BAG_L4': 0.222, 'XGBoost_BAG_L4': 0.167, 'RandomForestMSE_BAG_L4': 0.056}
# 	-1.0443	 = Validation score   (-root_mean_squared_error)
# 	0.96s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Excluded models: ['KNN'] (Specified by `excluded_model_types`)
# Fitting 106 L5 models, fit_strategy="sequential" ...
# Fitting model: LightGBMXT_BAG_L5 ... Training model for up to 1444.16s of the 1444.09s of remaining time.
# 	Memory not enough to fit 8 folds in parallel. Will train 4 folds in parallel instead (Estimated 17.09% memory usage per fold, 68.37%/80.00% total).
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=3, gpus=0, memory=17.09%)
# 2024-12-23 14:33:40,755	ERROR worker.py:422 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::_ray_fit() (pid=251662, ip=192.168.1.84)
#   File "/mnt/data/Projects/insurance/.venv/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 413, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
#   File "/mnt/data/Projects/insurance/.venv/lib/python3.11/site-packages/autogluon/core/models/abstract/abstract_model.py", line 925, in fit
#     out = self._fit(**kwargs)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/mnt/data/Projects/insurance/.venv/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 224, in _fit
#     raise TimeLimitExceeded
# autogluon.core.utils.exceptions.TimeLimitExceeded
# 2024-12-23 14:33:40,755	ERROR worker.py:422 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2024-12-23 14:33:40,756	ERROR worker.py:422 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 	-1.0446	 = Validation score   (-root_mean_squared_error)
# 	29.59s	 = Training   runtime
# 	1.91s	 = Validation runtime
# Fitting model: LightGBM_BAG_L5 ... Training model for up to 1412.71s of the 1412.64s of remaining time.
# 	Memory not enough to fit 8 folds in parallel. Will train 4 folds in parallel instead (Estimated 17.17% memory usage per fold, 68.68%/80.00% total).
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=3, gpus=0, memory=17.17%)
# 	-1.0445	 = Validation score   (-root_mean_squared_error)
# 	20.21s	 = Training   runtime
# 	1.19s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L5 ... Training model for up to 1390.71s of the 1390.64s of remaining time.
# 	Warning: Reducing model 'n_estimators' from 300 -> 191 due to low time. Expected time usage reduced from 2177.4s -> 1390.1s...
# 	-1.0474	 = Validation score   (-root_mean_squared_error)
# 	1032.68s	 = Training   runtime
# 	16.71s	 = Validation runtime
# Fitting model: CatBoost_BAG_L5 ... Training model for up to 340.67s of the 340.61s of remaining time.
# 	Memory not enough to fit 8 folds in parallel. Will train 4 folds in parallel instead (Estimated 18.39% memory usage per fold, 73.57%/80.00% total).
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=3, gpus=0, memory=18.39%)
# 	-1.074	 = Validation score   (-root_mean_squared_error)
# 	188.96s	 = Training   runtime
# 	1.13s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L5 ... Training model for up to 149.68s of the 149.61s of remaining time.
# 	Warning: Reducing model 'n_estimators' from 300 -> 111 due to low time. Expected time usage reduced from 399.7s -> 149.0s...
# 	Not enough time to generate out-of-fold predictions for model. Estimated time required was 33.26s compared to 27.9s of available time.
# 	Time limit exceeded... Skipping ExtraTreesMSE_BAG_L5.
# Fitting model: WeightedEnsemble_L6 ... Training model for up to 360.00s of the -20.24s of remaining time.
# 	Ensemble Weights: {'LightGBM_BAG_L2': 0.12, 'XGBoost_BAG_L2': 0.12, 'XGBoost_BAG_L3': 0.12, 'LightGBM_BAG_L4': 0.12, 'LightGBMXT_BAG_L4': 0.08, 'XGBoost_BAG_L4': 0.08, 'RandomForestMSE_BAG_L2': 0.04, 'ExtraTreesMSE_BAG_L2': 0.04, 'LightGBMXT_BAG_L3': 0.04, 'LightGBM_BAG_L3': 0.04, 'RandomForestMSE_BAG_L3': 0.04, 'NeuralNetFastAI_BAG_L3': 0.04, 'RandomForestMSE_BAG_L4': 0.04, 'LightGBM_BAG_L5': 0.04, 'RandomForestMSE_BAG_L5': 0.04}
# 	-1.0443	 = Validation score   (-root_mean_squared_error)
# 	3.54s	 = Training   runtime
# 	0.01s	 = Validation runtime
# AutoGluon training complete, total runtime = 16170.75s ... Best model: WeightedEnsemble_L6 | Estimated inference throughput: 538.9 rows/s (150000 batch size)
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("/mnt/data/Projects/insurance/notebooks/AutogluonModels/ag-20241223_135741")

# %%
predictor.leaderboard()
# Out:
#                      model  score_val              eval_metric  pred_time_val  \
# 0      WeightedEnsemble_L6  -1.044272  root_mean_squared_error     446.168089
# 1      WeightedEnsemble_L4  -1.044295  root_mean_squared_error     362.922553
# 2      WeightedEnsemble_L5  -1.044320  root_mean_squared_error     409.507833
# 3      WeightedEnsemble_L3  -1.044359  root_mean_squared_error     293.854346
# 4          LightGBM_BAG_L3  -1.044398  root_mean_squared_error     305.645274
# 5          LightGBM_BAG_L4  -1.044400  root_mean_squared_error     372.844972
# 6   NeuralNetFastAI_BAG_L4  -1.044414  root_mean_squared_error     378.125066
# 7   NeuralNetFastAI_BAG_L3  -1.044424  root_mean_squared_error     310.341584
# 8        LightGBMXT_BAG_L3  -1.044452  root_mean_squared_error     306.374881
# 9          LightGBM_BAG_L5  -1.044452  root_mean_squared_error     429.452525
# 10          XGBoost_BAG_L3  -1.044457  root_mean_squared_error     307.728761
# 11       LightGBMXT_BAG_L4  -1.044458  root_mean_squared_error     373.214553
# 12         LightGBM_BAG_L2  -1.044493  root_mean_squared_error     238.422894
# 13          XGBoost_BAG_L4  -1.044502  root_mean_squared_error     374.620562
# 14          XGBoost_BAG_L2  -1.044517  root_mean_squared_error     240.557946
# 15       LightGBMXT_BAG_L5  -1.044627  root_mean_squared_error     430.181618
# 16    LightGBMLarge_BAG_L2  -1.044653  root_mean_squared_error     239.182976
# 17    CatBoost_r177_BAG_L2  -1.044670  root_mean_squared_error     237.276511
# 18  NeuralNetFastAI_BAG_L2  -1.044799  root_mean_squared_error     244.638805
# 19       LightGBMXT_BAG_L2  -1.044819  root_mean_squared_error     238.105259
# 20     WeightedEnsemble_L2  -1.045121  root_mean_squared_error      50.424677
# 21    ExtraTreesMSE_BAG_L2  -1.045466  root_mean_squared_error     256.486324
# 22    ExtraTreesMSE_BAG_L3  -1.045533  root_mean_squared_error     324.153287
# 23    ExtraTreesMSE_BAG_L4  -1.045625  root_mean_squared_error     390.062438
# 24          XGBoost_BAG_L1  -1.046040  root_mean_squared_error       4.725130
# 25         LightGBM_BAG_L1  -1.046221  root_mean_squared_error      24.197000
# 26  RandomForestMSE_BAG_L2  -1.046506  root_mean_squared_error     261.526885
# 27  RandomForestMSE_BAG_L3  -1.046577  root_mean_squared_error     330.963220
# 28  RandomForestMSE_BAG_L4  -1.046649  root_mean_squared_error     397.484591
# 29  RandomForestMSE_BAG_L1  -1.047124  root_mean_squared_error      21.488080
# 30    LightGBMLarge_BAG_L3  -1.047294  root_mean_squared_error     305.434420
# 31  RandomForestMSE_BAG_L5  -1.047355  root_mean_squared_error     444.974143
# 32    ExtraTreesMSE_BAG_L1  -1.047603  root_mean_squared_error      19.109107
# 33       LightGBMXT_BAG_L1  -1.049813  root_mean_squared_error     159.593293
# 34         CatBoost_BAG_L2  -1.060613  root_mean_squared_error     237.228958
# 35  NeuralNetFastAI_BAG_L1  -1.064635  root_mean_squared_error       7.526115
# 36   NeuralNetTorch_BAG_L2  -1.068922  root_mean_squared_error     243.553675
# 37         CatBoost_BAG_L4  -1.070692  root_mean_squared_error     372.101730
# 38         CatBoost_BAG_L1  -1.070814  root_mean_squared_error       0.308118
# 39         CatBoost_BAG_L5  -1.074026  root_mean_squared_error     429.393337
# 40         CatBoost_BAG_L3  -1.076267  root_mean_squared_error     305.077278
# 41   NeuralNetTorch_BAG_L3  -1.078375  root_mean_squared_error     311.648256
#
#         fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  \
# 0   15422.868270                0.008758           3.540444            6
# 1   10982.049283                0.008795           1.052770            4
# 2   13719.689279                0.009139           0.962005            5
# 3    6914.212276                0.008862           1.330885            3
# 4    8099.388272                1.186625          21.083313            3
# 5   11536.540823                1.147210          20.324388            4
# 6   11692.989540                6.427303         176.773105            4
# 7    8446.502449                5.882934         368.197491            3
# 8    8104.739532                1.916231          26.434574            3
# 9   14386.649409                1.185189          20.209351            5
# 10   8140.624862                3.270112          62.319904            3
# 11  11539.975375                1.516790          23.758940            4
# 12   4239.378297                1.476052          22.845784            2
# 13  11575.319075                2.922799          59.102640            4
# 14   4276.004129                3.611103          59.471616            2
# 15  14396.034853                1.914282          29.594795            5
# 16   4248.579008                2.236133          32.046495            2
# 17   4268.127079                0.329668          51.594566            2
# 18   5011.158798                7.691963         794.626285            2
# 19   4251.047434                1.158416          34.514921            2
# 20    766.427903                0.014468           1.282545            2
# 21   4707.341048               19.539482         490.808535            2
# 22   8547.659286               19.694637         469.354328            3
# 23  11996.666445               18.364676         480.450011            4
# 24     68.548366                4.725130          68.548366            1
# 25     67.229218               24.197000          67.229218            1
# 26   5545.129171               24.580042        1328.596658            2
# 27  10033.606903               26.504570        1955.301945            3
# 28  13438.768199               25.786829        1922.551765            4
# 29    629.367773               21.488080         629.367773            1
# 30   8095.181852                0.975770          16.876894            3
# 31  15399.118475               16.706806        1032.678417            5
# 32    342.293046               19.109107         342.293046            1
# 33    310.900032              159.593293         310.900032            1
# 34   4865.350760                0.282116         648.818247            2
# 35    186.887596                7.526115         186.887596            1
# 36   4614.981851                6.606832         398.449338            2
# 37  11683.479208                0.403967         167.262774            4
# 38   2611.306482                0.308118        2611.306482            1
# 39  14555.403346                1.126001         188.963288            5
# 40   8504.635640                0.618628         426.330682            3
# 41   8170.317304                7.189606          92.012346            3
#
#     can_infer  fit_order
# 0        True         42
# 1        True         29
# 2        True         37
# 3        True         19
# 4        True         21
# 5        True         31
# 6        True         35
# 7        True         25
# 8        True         20
# 9        True         39
# 10       True         26
# 11       True         30
# 12       True         10
# 13       True         36
# 14       True         15
# 15       True         38
# 16       True         17
# 17       True         18
# 18       True         14
# 19       True          9
# 20       True          8
# 21       True         13
# 22       True         24
# 23       True         34
# 24       True          7
# 25       True          2
# 26       True         11
# 27       True         22
# 28       True         32
# 29       True          3
# 30       True         28
# 31       True         40
# 32       True          5
# 33       True          1
# 34       True         12
# 35       True          6
# 36       True         16
# 37       True         33
# 38       True          4
# 39       True         41
# 40       True         23
# 41       True         27

# %%
predictor.fit_summary(show_plot=True)
# Out:
# *** Summary of fit() ***
# Estimated performance of each model:
#                      model  score_val              eval_metric  pred_time_val      fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0      WeightedEnsemble_L6  -1.044272  root_mean_squared_error     446.168089  15422.868270                0.008758           3.540444            6       True         42
# 1      WeightedEnsemble_L4  -1.044295  root_mean_squared_error     362.922553  10982.049283                0.008795           1.052770            4       True         29
# 2      WeightedEnsemble_L5  -1.044320  root_mean_squared_error     409.507833  13719.689279                0.009139           0.962005            5       True         37
# 3      WeightedEnsemble_L3  -1.044359  root_mean_squared_error     293.854346   6914.212276                0.008862           1.330885            3       True         19
# 4          LightGBM_BAG_L3  -1.044398  root_mean_squared_error     305.645274   8099.388272                1.186625          21.083313            3       True         21
# 5          LightGBM_BAG_L4  -1.044400  root_mean_squared_error     372.844972  11536.540823                1.147210          20.324388            4       True         31
# 6   NeuralNetFastAI_BAG_L4  -1.044414  root_mean_squared_error     378.125066  11692.989540                6.427303         176.773105            4       True         35
# 7   NeuralNetFastAI_BAG_L3  -1.044424  root_mean_squared_error     310.341584   8446.502449                5.882934         368.197491            3       True         25
# 8        LightGBMXT_BAG_L3  -1.044452  root_mean_squared_error     306.374881   8104.739532                1.916231          26.434574            3       True         20
# 9          LightGBM_BAG_L5  -1.044452  root_mean_squared_error     429.452525  14386.649409                1.185189          20.209351            5       True         39
# 10          XGBoost_BAG_L3  -1.044457  root_mean_squared_error     307.728761   8140.624862                3.270112          62.319904            3       True         26
# 11       LightGBMXT_BAG_L4  -1.044458  root_mean_squared_error     373.214553  11539.975375                1.516790          23.758940            4       True         30
# 12         LightGBM_BAG_L2  -1.044493  root_mean_squared_error     238.422894   4239.378297                1.476052          22.845784            2       True         10
# 13          XGBoost_BAG_L4  -1.044502  root_mean_squared_error     374.620562  11575.319075                2.922799          59.102640            4       True         36
# 14          XGBoost_BAG_L2  -1.044517  root_mean_squared_error     240.557946   4276.004129                3.611103          59.471616            2       True         15
# 15       LightGBMXT_BAG_L5  -1.044627  root_mean_squared_error     430.181618  14396.034853                1.914282          29.594795            5       True         38
# 16    LightGBMLarge_BAG_L2  -1.044653  root_mean_squared_error     239.182976   4248.579008                2.236133          32.046495            2       True         17
# 17    CatBoost_r177_BAG_L2  -1.044670  root_mean_squared_error     237.276511   4268.127079                0.329668          51.594566            2       True         18
# 18  NeuralNetFastAI_BAG_L2  -1.044799  root_mean_squared_error     244.638805   5011.158798                7.691963         794.626285            2       True         14
# 19       LightGBMXT_BAG_L2  -1.044819  root_mean_squared_error     238.105259   4251.047434                1.158416          34.514921            2       True          9
# 20     WeightedEnsemble_L2  -1.045121  root_mean_squared_error      50.424677    766.427903                0.014468           1.282545            2       True          8
# 21    ExtraTreesMSE_BAG_L2  -1.045466  root_mean_squared_error     256.486324   4707.341048               19.539482         490.808535            2       True         13
# 22    ExtraTreesMSE_BAG_L3  -1.045533  root_mean_squared_error     324.153287   8547.659286               19.694637         469.354328            3       True         24
# 23    ExtraTreesMSE_BAG_L4  -1.045625  root_mean_squared_error     390.062438  11996.666445               18.364676         480.450011            4       True         34
# 24          XGBoost_BAG_L1  -1.046040  root_mean_squared_error       4.725130     68.548366                4.725130          68.548366            1       True          7
# 25         LightGBM_BAG_L1  -1.046221  root_mean_squared_error      24.197000     67.229218               24.197000          67.229218            1       True          2
# 26  RandomForestMSE_BAG_L2  -1.046506  root_mean_squared_error     261.526885   5545.129171               24.580042        1328.596658            2       True         11
# 27  RandomForestMSE_BAG_L3  -1.046577  root_mean_squared_error     330.963220  10033.606903               26.504570        1955.301945            3       True         22
# 28  RandomForestMSE_BAG_L4  -1.046649  root_mean_squared_error     397.484591  13438.768199               25.786829        1922.551765            4       True         32
# 29  RandomForestMSE_BAG_L1  -1.047124  root_mean_squared_error      21.488080    629.367773               21.488080         629.367773            1       True          3
# 30    LightGBMLarge_BAG_L3  -1.047294  root_mean_squared_error     305.434420   8095.181852                0.975770          16.876894            3       True         28
# 31  RandomForestMSE_BAG_L5  -1.047355  root_mean_squared_error     444.974143  15399.118475               16.706806        1032.678417            5       True         40
# 32    ExtraTreesMSE_BAG_L1  -1.047603  root_mean_squared_error      19.109107    342.293046               19.109107         342.293046            1       True          5
# 33       LightGBMXT_BAG_L1  -1.049813  root_mean_squared_error     159.593293    310.900032              159.593293         310.900032            1       True          1
# 34         CatBoost_BAG_L2  -1.060613  root_mean_squared_error     237.228958   4865.350760                0.282116         648.818247            2       True         12
# 35  NeuralNetFastAI_BAG_L1  -1.064635  root_mean_squared_error       7.526115    186.887596                7.526115         186.887596            1       True          6
# 36   NeuralNetTorch_BAG_L2  -1.068922  root_mean_squared_error     243.553675   4614.981851                6.606832         398.449338            2       True         16
# 37         CatBoost_BAG_L4  -1.070692  root_mean_squared_error     372.101730  11683.479208                0.403967         167.262774            4       True         33
# 38         CatBoost_BAG_L1  -1.070814  root_mean_squared_error       0.308118   2611.306482                0.308118        2611.306482            1       True          4
# 39         CatBoost_BAG_L5  -1.074026  root_mean_squared_error     429.393337  14555.403346                1.126001         188.963288            5       True         41
# 40         CatBoost_BAG_L3  -1.076267  root_mean_squared_error     305.077278   8504.635640                0.618628         426.330682            3       True         23
# 41   NeuralNetTorch_BAG_L3  -1.078375  root_mean_squared_error     311.648256   8170.317304                7.189606          92.012346            3       True         27
# Number of models trained: 42
# Types of models trained:
# {'StackerEnsembleModel_NNFastAiTabular', 'StackerEnsembleModel_LGB', 'WeightedEnsembleModel', 'StackerEnsembleModel_RF', 'StackerEnsembleModel_XT', 'StackerEnsembleModel_CatBoost', 'StackerEnsembleModel_TabularNeuralNetTorch', 'StackerEnsembleModel_XGBoost'}
# Bagging used: True  (with 8 folds)
# Multi-layer stack-ensembling used: True  (with 6 levels)
# Feature Metadata (Processed):
# (raw dtype, special dtypes):
# ('category', [])  : 8 | ['Marital Status', 'Education Level', 'Occupation', 'Location', 'Policy Type', ...]
# ('float', [])     : 8 | ['Age', 'Annual Income', 'Number of Dependents', 'Health Score', 'Previous Claims', ...]
# ('int', [])       : 4 | ['year', 'month', 'day', 'dayofweek']
# ('int', ['bool']) : 2 | ['Gender', 'Smoking Status']
# Plot summary of models saved to file: /mnt/data/Projects/insurance/notebooks/AutogluonModels/ag-20241223_135741SummaryOfModels.html
# *** End of fit() summary ***
# {'model_types': {'LightGBMXT_BAG_L1': 'StackerEnsembleModel_LGB',
#   'LightGBM_BAG_L1': 'StackerEnsembleModel_LGB',
#   'RandomForestMSE_BAG_L1': 'StackerEnsembleModel_RF',
#   'CatBoost_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'ExtraTreesMSE_BAG_L1': 'StackerEnsembleModel_XT',
#   'NeuralNetFastAI_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'XGBoost_BAG_L1': 'StackerEnsembleModel_XGBoost',
#   'WeightedEnsemble_L2': 'WeightedEnsembleModel',
#   'LightGBMXT_BAG_L2': 'StackerEnsembleModel_LGB',
#   'LightGBM_BAG_L2': 'StackerEnsembleModel_LGB',
#   'RandomForestMSE_BAG_L2': 'StackerEnsembleModel_RF',
#   'CatBoost_BAG_L2': 'StackerEnsembleModel_CatBoost',
#   'ExtraTreesMSE_BAG_L2': 'StackerEnsembleModel_XT',
#   'NeuralNetFastAI_BAG_L2': 'StackerEnsembleModel_NNFastAiTabular',
#   'XGBoost_BAG_L2': 'StackerEnsembleModel_XGBoost',
#   'NeuralNetTorch_BAG_L2': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'LightGBMLarge_BAG_L2': 'StackerEnsembleModel_LGB',
#   'CatBoost_r177_BAG_L2': 'StackerEnsembleModel_CatBoost',
#   'WeightedEnsemble_L3': 'WeightedEnsembleModel',
#   'LightGBMXT_BAG_L3': 'StackerEnsembleModel_LGB',
#   'LightGBM_BAG_L3': 'StackerEnsembleModel_LGB',
#   'RandomForestMSE_BAG_L3': 'StackerEnsembleModel_RF',
#   'CatBoost_BAG_L3': 'StackerEnsembleModel_CatBoost',
#   'ExtraTreesMSE_BAG_L3': 'StackerEnsembleModel_XT',
#   'NeuralNetFastAI_BAG_L3': 'StackerEnsembleModel_NNFastAiTabular',
#   'XGBoost_BAG_L3': 'StackerEnsembleModel_XGBoost',
#   'NeuralNetTorch_BAG_L3': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'LightGBMLarge_BAG_L3': 'StackerEnsembleModel_LGB',
#   'WeightedEnsemble_L4': 'WeightedEnsembleModel',
#   'LightGBMXT_BAG_L4': 'StackerEnsembleModel_LGB',
#   'LightGBM_BAG_L4': 'StackerEnsembleModel_LGB',
#   'RandomForestMSE_BAG_L4': 'StackerEnsembleModel_RF',
#   'CatBoost_BAG_L4': 'StackerEnsembleModel_CatBoost',
#   'ExtraTreesMSE_BAG_L4': 'StackerEnsembleModel_XT',
#   'NeuralNetFastAI_BAG_L4': 'StackerEnsembleModel_NNFastAiTabular',
#   'XGBoost_BAG_L4': 'StackerEnsembleModel_XGBoost',
#   'WeightedEnsemble_L5': 'WeightedEnsembleModel',
#   'LightGBMXT_BAG_L5': 'StackerEnsembleModel_LGB',
#   'LightGBM_BAG_L5': 'StackerEnsembleModel_LGB',
#   'RandomForestMSE_BAG_L5': 'StackerEnsembleModel_RF',
#   'CatBoost_BAG_L5': 'StackerEnsembleModel_CatBoost',
#   'WeightedEnsemble_L6': 'WeightedEnsembleModel'},
#  'model_performance': {'LightGBMXT_BAG_L1': -1.0498134593511368,
#   'LightGBM_BAG_L1': -1.0462207195890671,
#   'RandomForestMSE_BAG_L1': -1.0471244733162297,
#   'CatBoost_BAG_L1': -1.0708141258734543,
#   'ExtraTreesMSE_BAG_L1': -1.0476028102153507,
#   'NeuralNetFastAI_BAG_L1': -1.0646349557699024,
#   'XGBoost_BAG_L1': -1.0460404250944497,
#   'WeightedEnsemble_L2': -1.0451212441505227,
#   'LightGBMXT_BAG_L2': -1.0448193462993296,
#   'LightGBM_BAG_L2': -1.0444934658817353,
#   'RandomForestMSE_BAG_L2': -1.0465060151935455,
#   'CatBoost_BAG_L2': -1.060613335497969,
#   'ExtraTreesMSE_BAG_L2': -1.04546627890178,
#   'NeuralNetFastAI_BAG_L2': -1.0447993012502923,
#   'XGBoost_BAG_L2': -1.0445173875692542,
#   'NeuralNetTorch_BAG_L2': -1.0689224475810961,
#   'LightGBMLarge_BAG_L2': -1.0446527384978865,
#   'CatBoost_r177_BAG_L2': -1.044669809993336,
#   'WeightedEnsemble_L3': -1.044358907150334,
#   'LightGBMXT_BAG_L3': -1.0444516767313687,
#   'LightGBM_BAG_L3': -1.044398299789286,
#   'RandomForestMSE_BAG_L3': -1.046576647849268,
#   'CatBoost_BAG_L3': -1.0762673810132004,
#   'ExtraTreesMSE_BAG_L3': -1.0455325637661002,
#   'NeuralNetFastAI_BAG_L3': -1.044424181364359,
#   'XGBoost_BAG_L3': -1.0444571295039682,
#   'NeuralNetTorch_BAG_L3': -1.0783753813478374,
#   'LightGBMLarge_BAG_L3': -1.0472942532822587,
#   'WeightedEnsemble_L4': -1.0442954719542987,
#   'LightGBMXT_BAG_L4': -1.0444579823004196,
#   'LightGBM_BAG_L4': -1.0443995425775978,
#   'RandomForestMSE_BAG_L4': -1.0466493218603703,
#   'CatBoost_BAG_L4': -1.0706920729382836,
#   'ExtraTreesMSE_BAG_L4': -1.0456254268988017,
#   'NeuralNetFastAI_BAG_L4': -1.0444139200378793,
#   'XGBoost_BAG_L4': -1.044501934443218,
#   'WeightedEnsemble_L5': -1.0443199319770855,
#   'LightGBMXT_BAG_L5': -1.044626512191481,
#   'LightGBM_BAG_L5': -1.0444519067585476,
#   'RandomForestMSE_BAG_L5': -1.0473550725336704,
#   'CatBoost_BAG_L5': -1.0740261229305963,
#   'WeightedEnsemble_L6': -1.044271541805893},
#  'model_best': 'WeightedEnsemble_L6',
#  'model_paths': {'LightGBMXT_BAG_L1': ['LightGBMXT_BAG_L1'],
#   'LightGBM_BAG_L1': ['LightGBM_BAG_L1'],
#   'RandomForestMSE_BAG_L1': ['RandomForestMSE_BAG_L1'],
#   'CatBoost_BAG_L1': ['CatBoost_BAG_L1'],
#   'ExtraTreesMSE_BAG_L1': ['ExtraTreesMSE_BAG_L1'],
#   'NeuralNetFastAI_BAG_L1': ['NeuralNetFastAI_BAG_L1'],
#   'XGBoost_BAG_L1': ['XGBoost_BAG_L1'],
#   'WeightedEnsemble_L2': ['WeightedEnsemble_L2'],
#   'LightGBMXT_BAG_L2': ['LightGBMXT_BAG_L2'],
#   'LightGBM_BAG_L2': ['LightGBM_BAG_L2'],
#   'RandomForestMSE_BAG_L2': ['RandomForestMSE_BAG_L2'],
#   'CatBoost_BAG_L2': ['CatBoost_BAG_L2'],
#   'ExtraTreesMSE_BAG_L2': ['ExtraTreesMSE_BAG_L2'],
#   'NeuralNetFastAI_BAG_L2': ['NeuralNetFastAI_BAG_L2'],
#   'XGBoost_BAG_L2': ['XGBoost_BAG_L2'],
#   'NeuralNetTorch_BAG_L2': ['NeuralNetTorch_BAG_L2'],
#   'LightGBMLarge_BAG_L2': ['LightGBMLarge_BAG_L2'],
#   'CatBoost_r177_BAG_L2': ['CatBoost_r177_BAG_L2'],
#   'WeightedEnsemble_L3': ['WeightedEnsemble_L3'],
#   'LightGBMXT_BAG_L3': ['LightGBMXT_BAG_L3'],
#   'LightGBM_BAG_L3': ['LightGBM_BAG_L3'],
#   'RandomForestMSE_BAG_L3': ['RandomForestMSE_BAG_L3'],
#   'CatBoost_BAG_L3': ['CatBoost_BAG_L3'],
#   'ExtraTreesMSE_BAG_L3': ['ExtraTreesMSE_BAG_L3'],
#   'NeuralNetFastAI_BAG_L3': ['NeuralNetFastAI_BAG_L3'],
#   'XGBoost_BAG_L3': ['XGBoost_BAG_L3'],
#   'NeuralNetTorch_BAG_L3': ['NeuralNetTorch_BAG_L3'],
#   'LightGBMLarge_BAG_L3': ['LightGBMLarge_BAG_L3'],
#   'WeightedEnsemble_L4': ['WeightedEnsemble_L4'],
#   'LightGBMXT_BAG_L4': ['LightGBMXT_BAG_L4'],
#   'LightGBM_BAG_L4': ['LightGBM_BAG_L4'],
#   'RandomForestMSE_BAG_L4': ['RandomForestMSE_BAG_L4'],
#   'CatBoost_BAG_L4': ['CatBoost_BAG_L4'],
#   'ExtraTreesMSE_BAG_L4': ['ExtraTreesMSE_BAG_L4'],
#   'NeuralNetFastAI_BAG_L4': ['NeuralNetFastAI_BAG_L4'],
#   'XGBoost_BAG_L4': ['XGBoost_BAG_L4'],
#   'WeightedEnsemble_L5': ['WeightedEnsemble_L5'],
#   'LightGBMXT_BAG_L5': ['LightGBMXT_BAG_L5'],
#   'LightGBM_BAG_L5': ['LightGBM_BAG_L5'],
#   'RandomForestMSE_BAG_L5': ['RandomForestMSE_BAG_L5'],
#   'CatBoost_BAG_L5': ['CatBoost_BAG_L5'],
#   'WeightedEnsemble_L6': ['WeightedEnsemble_L6']},
#  'model_fit_times': {'LightGBMXT_BAG_L1': 310.9000315666199,
#   'LightGBM_BAG_L1': 67.22921824455261,
#   'RandomForestMSE_BAG_L1': 629.3677732944489,
#   'CatBoost_BAG_L1': 2611.306482076645,
#   'ExtraTreesMSE_BAG_L1': 342.2930462360382,
#   'NeuralNetFastAI_BAG_L1': 186.88759589195251,
#   'XGBoost_BAG_L1': 68.54836583137512,
#   'WeightedEnsemble_L2': 1.2825453281402588,
#   'LightGBMXT_BAG_L2': 34.51492094993591,
#   'LightGBM_BAG_L2': 22.845783710479736,
#   'RandomForestMSE_BAG_L2': 1328.5966577529907,
#   'CatBoost_BAG_L2': 648.8182470798492,
#   'ExtraTreesMSE_BAG_L2': 490.80853509902954,
#   'NeuralNetFastAI_BAG_L2': 794.6262853145599,
#   'XGBoost_BAG_L2': 59.47161602973938,
#   'NeuralNetTorch_BAG_L2': 398.44933819770813,
#   'LightGBMLarge_BAG_L2': 32.04649472236633,
#   'CatBoost_r177_BAG_L2': 51.594566345214844,
#   'WeightedEnsemble_L3': 1.3308851718902588,
#   'LightGBMXT_BAG_L3': 26.434573888778687,
#   'LightGBM_BAG_L3': 21.08331322669983,
#   'RandomForestMSE_BAG_L3': 1955.301944732666,
#   'CatBoost_BAG_L3': 426.33068203926086,
#   'ExtraTreesMSE_BAG_L3': 469.3543281555176,
#   'NeuralNetFastAI_BAG_L3': 368.19749093055725,
#   'XGBoost_BAG_L3': 62.31990385055542,
#   'NeuralNetTorch_BAG_L3': 92.01234555244446,
#   'LightGBMLarge_BAG_L3': 16.876893997192383,
#   'WeightedEnsemble_L4': 1.052769660949707,
#   'LightGBMXT_BAG_L4': 23.75894021987915,
#   'LightGBM_BAG_L4': 20.324388027191162,
#   'RandomForestMSE_BAG_L4': 1922.5517647266388,
#   'CatBoost_BAG_L4': 167.26277375221252,
#   'ExtraTreesMSE_BAG_L4': 480.4500107765198,
#   'NeuralNetFastAI_BAG_L4': 176.7731053829193,
#   'XGBoost_BAG_L4': 59.10264039039612,
#   'WeightedEnsemble_L5': 0.9620053768157959,
#   'LightGBMXT_BAG_L5': 29.59479522705078,
#   'LightGBM_BAG_L5': 20.209351062774658,
#   'RandomForestMSE_BAG_L5': 1032.6784174442291,
#   'CatBoost_BAG_L5': 188.96328830718994,
#   'WeightedEnsemble_L6': 3.5404438972473145},
#  'model_pred_times': {'LightGBMXT_BAG_L1': 159.59329271316528,
#   'LightGBM_BAG_L1': 24.196999549865723,
#   'RandomForestMSE_BAG_L1': 21.48807954788208,
#   'CatBoost_BAG_L1': 0.3081183433532715,
#   'ExtraTreesMSE_BAG_L1': 19.10910725593567,
#   'NeuralNetFastAI_BAG_L1': 7.52611517906189,
#   'XGBoost_BAG_L1': 4.725129842758179,
#   'WeightedEnsemble_L2': 0.014467954635620117,
#   'LightGBMXT_BAG_L2': 1.1584162712097168,
#   'LightGBM_BAG_L2': 1.4760515689849854,
#   'RandomForestMSE_BAG_L2': 24.580042123794556,
#   'CatBoost_BAG_L2': 0.2821159362792969,
#   'ExtraTreesMSE_BAG_L2': 19.53948163986206,
#   'NeuralNetFastAI_BAG_L2': 7.691962957382202,
#   'XGBoost_BAG_L2': 3.6111032962799072,
#   'NeuralNetTorch_BAG_L2': 6.606832265853882,
#   'LightGBMLarge_BAG_L2': 2.236133098602295,
#   'CatBoost_r177_BAG_L2': 0.3296682834625244,
#   'WeightedEnsemble_L3': 0.008861541748046875,
#   'LightGBMXT_BAG_L3': 1.9162311553955078,
#   'LightGBM_BAG_L3': 1.186624526977539,
#   'RandomForestMSE_BAG_L3': 26.50456976890564,
#   'CatBoost_BAG_L3': 0.6186282634735107,
#   'ExtraTreesMSE_BAG_L3': 19.694636821746826,
#   'NeuralNetFastAI_BAG_L3': 5.882934331893921,
#   'XGBoost_BAG_L3': 3.270111560821533,
#   'NeuralNetTorch_BAG_L3': 7.189605951309204,
#   'LightGBMLarge_BAG_L3': 0.9757704734802246,
#   'WeightedEnsemble_L4': 0.008794546127319336,
#   'LightGBMXT_BAG_L4': 1.5167899131774902,
#   'LightGBM_BAG_L4': 1.147209644317627,
#   'RandomForestMSE_BAG_L4': 25.786828756332397,
#   'CatBoost_BAG_L4': 0.40396690368652344,
#   'ExtraTreesMSE_BAG_L4': 18.364675760269165,
#   'NeuralNetFastAI_BAG_L4': 6.427303075790405,
#   'XGBoost_BAG_L4': 2.9227993488311768,
#   'WeightedEnsemble_L5': 0.009139060974121094,
#   'LightGBMXT_BAG_L5': 1.9142818450927734,
#   'LightGBM_BAG_L5': 1.1851885318756104,
#   'RandomForestMSE_BAG_L5': 16.706806421279907,
#   'CatBoost_BAG_L5': 1.1260011196136475,
#   'WeightedEnsemble_L6': 0.008758068084716797},
#  'num_bag_folds': 8,
#  'max_stack_level': 6,
#  'model_hyperparams': {'LightGBMXT_BAG_L1': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'LightGBM_BAG_L1': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'RandomForestMSE_BAG_L1': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'CatBoost_BAG_L1': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'ExtraTreesMSE_BAG_L1': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'NeuralNetFastAI_BAG_L1': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'XGBoost_BAG_L1': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'WeightedEnsemble_L2': {'use_orig_features': False,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'LightGBMXT_BAG_L2': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'LightGBM_BAG_L2': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'RandomForestMSE_BAG_L2': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'CatBoost_BAG_L2': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'ExtraTreesMSE_BAG_L2': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'NeuralNetFastAI_BAG_L2': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'XGBoost_BAG_L2': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'NeuralNetTorch_BAG_L2': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'LightGBMLarge_BAG_L2': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'CatBoost_r177_BAG_L2': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'WeightedEnsemble_L3': {'use_orig_features': False,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'LightGBMXT_BAG_L3': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'LightGBM_BAG_L3': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'RandomForestMSE_BAG_L3': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'CatBoost_BAG_L3': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'ExtraTreesMSE_BAG_L3': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'NeuralNetFastAI_BAG_L3': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'XGBoost_BAG_L3': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'NeuralNetTorch_BAG_L3': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'LightGBMLarge_BAG_L3': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'WeightedEnsemble_L4': {'use_orig_features': False,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'LightGBMXT_BAG_L4': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'LightGBM_BAG_L4': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'RandomForestMSE_BAG_L4': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'CatBoost_BAG_L4': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'ExtraTreesMSE_BAG_L4': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'NeuralNetFastAI_BAG_L4': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'XGBoost_BAG_L4': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'WeightedEnsemble_L5': {'use_orig_features': False,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'LightGBMXT_BAG_L5': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'LightGBM_BAG_L5': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'RandomForestMSE_BAG_L5': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'CatBoost_BAG_L5': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'WeightedEnsemble_L6': {'use_orig_features': False,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True}},
#  'leaderboard':                      model  score_val              eval_metric  pred_time_val  \
#  0      WeightedEnsemble_L6  -1.044272  root_mean_squared_error     446.168089
#  1      WeightedEnsemble_L4  -1.044295  root_mean_squared_error     362.922553
#  2      WeightedEnsemble_L5  -1.044320  root_mean_squared_error     409.507833
#  3      WeightedEnsemble_L3  -1.044359  root_mean_squared_error     293.854346
#  4          LightGBM_BAG_L3  -1.044398  root_mean_squared_error     305.645274
#  5          LightGBM_BAG_L4  -1.044400  root_mean_squared_error     372.844972
#  6   NeuralNetFastAI_BAG_L4  -1.044414  root_mean_squared_error     378.125066
#  7   NeuralNetFastAI_BAG_L3  -1.044424  root_mean_squared_error     310.341584
#  8        LightGBMXT_BAG_L3  -1.044452  root_mean_squared_error     306.374881
#  9          LightGBM_BAG_L5  -1.044452  root_mean_squared_error     429.452525
#  10          XGBoost_BAG_L3  -1.044457  root_mean_squared_error     307.728761
#  11       LightGBMXT_BAG_L4  -1.044458  root_mean_squared_error     373.214553
#  12         LightGBM_BAG_L2  -1.044493  root_mean_squared_error     238.422894
#  13          XGBoost_BAG_L4  -1.044502  root_mean_squared_error     374.620562
#  14          XGBoost_BAG_L2  -1.044517  root_mean_squared_error     240.557946
#  15       LightGBMXT_BAG_L5  -1.044627  root_mean_squared_error     430.181618
#  16    LightGBMLarge_BAG_L2  -1.044653  root_mean_squared_error     239.182976
#  17    CatBoost_r177_BAG_L2  -1.044670  root_mean_squared_error     237.276511
#  18  NeuralNetFastAI_BAG_L2  -1.044799  root_mean_squared_error     244.638805
#  19       LightGBMXT_BAG_L2  -1.044819  root_mean_squared_error     238.105259
#  20     WeightedEnsemble_L2  -1.045121  root_mean_squared_error      50.424677
#  21    ExtraTreesMSE_BAG_L2  -1.045466  root_mean_squared_error     256.486324
#  22    ExtraTreesMSE_BAG_L3  -1.045533  root_mean_squared_error     324.153287
#  23    ExtraTreesMSE_BAG_L4  -1.045625  root_mean_squared_error     390.062438
#  24          XGBoost_BAG_L1  -1.046040  root_mean_squared_error       4.725130
#  25         LightGBM_BAG_L1  -1.046221  root_mean_squared_error      24.197000
#  26  RandomForestMSE_BAG_L2  -1.046506  root_mean_squared_error     261.526885
#  27  RandomForestMSE_BAG_L3  -1.046577  root_mean_squared_error     330.963220
#  28  RandomForestMSE_BAG_L4  -1.046649  root_mean_squared_error     397.484591
#  29  RandomForestMSE_BAG_L1  -1.047124  root_mean_squared_error      21.488080
#  30    LightGBMLarge_BAG_L3  -1.047294  root_mean_squared_error     305.434420
#  31  RandomForestMSE_BAG_L5  -1.047355  root_mean_squared_error     444.974143
#  32    ExtraTreesMSE_BAG_L1  -1.047603  root_mean_squared_error      19.109107
#  33       LightGBMXT_BAG_L1  -1.049813  root_mean_squared_error     159.593293
#  34         CatBoost_BAG_L2  -1.060613  root_mean_squared_error     237.228958
#  35  NeuralNetFastAI_BAG_L1  -1.064635  root_mean_squared_error       7.526115
#  36   NeuralNetTorch_BAG_L2  -1.068922  root_mean_squared_error     243.553675
#  37         CatBoost_BAG_L4  -1.070692  root_mean_squared_error     372.101730
#  38         CatBoost_BAG_L1  -1.070814  root_mean_squared_error       0.308118
#  39         CatBoost_BAG_L5  -1.074026  root_mean_squared_error     429.393337
#  40         CatBoost_BAG_L3  -1.076267  root_mean_squared_error     305.077278
#  41   NeuralNetTorch_BAG_L3  -1.078375  root_mean_squared_error     311.648256
#
#          fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  \
#  0   15422.868270                0.008758           3.540444            6
#  1   10982.049283                0.008795           1.052770            4
#  2   13719.689279                0.009139           0.962005            5
#  3    6914.212276                0.008862           1.330885            3
#  4    8099.388272                1.186625          21.083313            3
#  5   11536.540823                1.147210          20.324388            4
#  6   11692.989540                6.427303         176.773105            4
#  7    8446.502449                5.882934         368.197491            3
#  8    8104.739532                1.916231          26.434574            3
#  9   14386.649409                1.185189          20.209351            5
#  10   8140.624862                3.270112          62.319904            3
#  11  11539.975375                1.516790          23.758940            4
#  12   4239.378297                1.476052          22.845784            2
#  13  11575.319075                2.922799          59.102640            4
#  14   4276.004129                3.611103          59.471616            2
#  15  14396.034853                1.914282          29.594795            5
#  16   4248.579008                2.236133          32.046495            2
#  17   4268.127079                0.329668          51.594566            2
#  18   5011.158798                7.691963         794.626285            2
#  19   4251.047434                1.158416          34.514921            2
#  20    766.427903                0.014468           1.282545            2
#  21   4707.341048               19.539482         490.808535            2
#  22   8547.659286               19.694637         469.354328            3
#  23  11996.666445               18.364676         480.450011            4
#  24     68.548366                4.725130          68.548366            1
#  25     67.229218               24.197000          67.229218            1
#  26   5545.129171               24.580042        1328.596658            2
#  27  10033.606903               26.504570        1955.301945            3
#  28  13438.768199               25.786829        1922.551765            4
#  29    629.367773               21.488080         629.367773            1
#  30   8095.181852                0.975770          16.876894            3
#  31  15399.118475               16.706806        1032.678417            5
#  32    342.293046               19.109107         342.293046            1
#  33    310.900032              159.593293         310.900032            1
#  34   4865.350760                0.282116         648.818247            2
#  35    186.887596                7.526115         186.887596            1
#  36   4614.981851                6.606832         398.449338            2
#  37  11683.479208                0.403967         167.262774            4
#  38   2611.306482                0.308118        2611.306482            1
#  39  14555.403346                1.126001         188.963288            5
#  40   8504.635640                0.618628         426.330682            3
#  41   8170.317304                7.189606          92.012346            3
#
#      can_infer  fit_order
#  0        True         42
#  1        True         29
#  2        True         37
#  3        True         19
#  4        True         21
#  5        True         31
#  6        True         35
#  7        True         25
#  8        True         20
#  9        True         39
#  10       True         26
#  11       True         30
#  12       True         10
#  13       True         36
#  14       True         15
#  15       True         38
#  16       True         17
#  17       True         18
#  18       True         14
#  19       True          9
#  20       True          8
#  21       True         13
#  22       True         24
#  23       True         34
#  24       True          7
#  25       True          2
#  26       True         11
#  27       True         22
#  28       True         32
#  29       True          3
#  30       True         28
#  31       True         40
#  32       True          5
#  33       True          1
#  34       True         12
#  35       True          6
#  36       True         16
#  37       True         33
#  38       True          4
#  39       True         41
#  40       True         23
#  41       True         27  }

# %%
import numpy as np
import pandas as pd

import xgboost as xgb

from insurance.common import OUT_PATH, PREP_DATA_PATH, RAW_DATA_PATH
from insurance.data_pipeline import get_feat_columns

from insurance.prepare_basic import prepare


df_test = pd.read_csv(RAW_DATA_PATH / "test.csv")
ids = df_test["id"].values
df_test = prepare(df=df_test)
df_test.to_feather(PREP_DATA_PATH / "test_prepared.feather")

feat_cols = get_feat_columns()
feat_names = feat_cols.names
df_test = df_test[feat_names]

df_test["Premium Amount"] = -1.0
X_test = data_pipeline.transform(df_test)
for col in feat_cols.categorical:
    X_test[col] = X_test[col].astype("category")


predictions = np.expm1(predictor.predict(X_test))

# Prepare submission file
submission = pd.DataFrame(
    {
        "id": ids,
        "Premium Amount": predictions,
    }
)
pred_file = OUT_PATH / "preds.csv"
submission.to_csv(pred_file, index=False)
print(f"Submission file saved to {pred_file}")
# Out:
# Submission file saved to /mnt/data/Projects/insurance/out/preds.csv
