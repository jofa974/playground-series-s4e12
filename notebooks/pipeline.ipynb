# %%
import numpy as np
import pandas as pd
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import FunctionTransformer, OneHotEncoder, OrdinalEncoder, StandardScaler
from dataclasses import dataclass, field, fields


@dataclass
class Features:
    numeric: list[str] = field(default_factory=list)
    categorical: list[str] = field(default_factory=list)
    ordinal: list[str] = field(default_factory=list)
    numeric_log: list[str] = field(default_factory=list)

    @property
    def names(self):
        to_return = []
        for f in fields(self):
            vals = getattr(self, f.name)
            if vals:
                to_return.extend(vals)
        return to_return


def get_feat_columns():
    numeric_feat_cols = [
        "Age",
        "Health Score",
        "Credit Score",
        "Insurance Duration",
        "Number of Dependents",
        "Vehicle Age",
    ]
    numeric_log_feat_cols = ["Annual Income"]
    categorical_feat_cols = [
        "Gender",
        "Marital Status",
        "Education Level",
        "Occupation",
        "Location",
        "Policy Type",
        "Customer Feedback",
        "Smoking Status",
        "Exercise Frequency",
        "Property Type",
    ]
    ordinal_feat_cols = [
        "Previous Claims",
    ]

    feat_cols = Features(
        numeric=numeric_feat_cols,
        numeric_log=numeric_log_feat_cols,
        categorical=categorical_feat_cols,
        ordinal=ordinal_feat_cols,
    )
    return feat_cols

# %%
feat_cols = get_feat_columns()

# Preprocessing pipeline
numeric_transformer = Pipeline(
    [
        ("imputer", SimpleImputer(strategy="median")),
        ("scaler", StandardScaler()),
    ]
)


def log1p(df: pd.DataFrame) -> pd.DataFrame:
    return np.log1p(df)


log_transformer = Pipeline(
    [
        ("imputer", SimpleImputer(strategy="median")),
        ("log", FunctionTransformer(np.log1p, validate=True, feature_names_out="one-to-one")),
        ("scaler", StandardScaler()),
    ]
)

# No need to OH encode bc XGBoost can deal with that.
cat_transformer = Pipeline(
    [
        ("imputer", SimpleImputer(strategy="most_frequent")),
    ]
)

ord_transformer = Pipeline(
    [
        ("imputer", SimpleImputer(strategy="most_frequent")),
        ("ordinal", OrdinalEncoder(handle_unknown="use_encoded_value", unknown_value=-1)),
    ]
)

transformers = []
if feat_cols.numeric:
    transformers.append(("num", numeric_transformer, feat_cols.numeric))
if feat_cols.numeric_log:
    transformers.append(("num_log", log_transformer, feat_cols.numeric_log))
if feat_cols.categorical:
    transformers.append(("cat", cat_transformer, feat_cols.categorical))
if feat_cols.ordinal:
    transformers.append(("ord", ord_transformer, feat_cols.ordinal))
preprocessor = ColumnTransformer(
    transformers=transformers, remainder="passthrough", verbose_feature_names_out=False
)

pipeline = Pipeline(
    [
        ("preprocessor", preprocessor),
    ]
)
pipeline.set_output(transform="pandas")
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['Age', 'Health Score',
#                                                    'Credit Score',
#                                                    'Insurance Duration',
#                                                    'Number of Dependents',
#                                                    'Vehicle Age']),
#                                                  ('num_log',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   (...
#                                                   ['Gender', 'Marital Status',
#                                                    'Education Level',
#                                                    'Occupation', 'Location',
#                                                    'Policy Type',
#                                                    'Customer Feedback',
#                                                    'Smoking Status',
#                                                    'Exercise Frequency',
#                                                    'Property Type']),
#                                                  ('ord',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('ordinal',
#                                                                    OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                                   unknown_value=-1))]),
#                                                   ['Previous Claims'])],
#                                    verbose_feature_names_out=False))])

# %%
df = pd.read_feather("../data/prepared/prepared_imputed_data.feather")

# %%
pipeline.fit(df).get_feature_names_out()
# Out:
# array(['Age', 'Health Score', 'Credit Score', 'Insurance Duration',
#        'Number of Dependents', 'Vehicle Age', 'Annual Income', 'Gender',
#        'Marital Status', 'Education Level', 'Occupation', 'Location',
#        'Policy Type', 'Customer Feedback', 'Smoking Status',
#        'Exercise Frequency', 'Property Type', 'Previous Claims',
#        'Policy Start Date', 'Premium Amount'], dtype=object)

# %%
pipeline.fit_transform(df)
# Out:
#               Age  Health Score  Credit Score  Insurance Duration  \
# 372605   0.808151     -1.476464     -0.681503           -0.777935
# 551204   1.403654     -0.082155     -1.794158           -0.777935
# 240320   1.254778      0.752953      0.013020            0.763890
# 1047361 -0.159542      0.058499      1.189457           -0.007023
# 555362   0.435961      0.096581     -1.942984           -0.392479
# ...           ...           ...           ...                 ...
# 110268  -0.829484     -0.810613     -1.879202           -0.007023
# 259178  -0.457294     -0.138349     -1.808332            1.534802
# 131932   0.138209     -0.033678      1.813111           -0.777935
# 671155   0.584837      1.360687     -1.057113           -1.548847
# 121958   1.180340     -0.082155      1.685545           -0.777935
#
#          Number of Dependents  Vehicle Age  Annual Income  Gender  \
# 372605              -0.006681     1.459463      -0.872407  Female
# 551204               1.473681    -1.137413       0.609442  Female
# 240320              -0.006681     1.632588      -1.512614  Female
# 1047361             -1.487043     1.286338      -0.499349    Male
# 555362              -0.006681    -0.964288       0.672599    Male
# ...                       ...          ...            ...     ...
# 110268               1.473681     1.459463      -1.388292  Female
# 259178              -0.006681     1.113213       1.062392    Male
# 131932              -1.487043    -0.271787       1.186012    Male
# 671155              -1.487043    -1.310538      -0.823763    Male
# 121958              -0.006681     1.632588       1.512184  Female
#
#         Marital Status Education Level Occupation  Location    Policy Type  \
# 372605         Married        Master's   Employed     Rural          Basic
# 551204         Married      Bachelor's   Employed  Suburban  Comprehensive
# 240320         Married      Bachelor's   Employed     Urban  Comprehensive
# 1047361       Divorced      Bachelor's   Employed     Rural          Basic
# 555362        Divorced             PhD   Employed  Suburban  Comprehensive
# ...                ...             ...        ...       ...            ...
# 110268          Single     High School   Employed  Suburban          Basic
# 259178        Divorced      Bachelor's   Employed     Urban  Comprehensive
# 131932         Married      Bachelor's   Employed     Urban        Premium
# 671155        Divorced      Bachelor's   Employed     Rural  Comprehensive
# 121958          Single             PhD   Employed     Urban        Premium
#
#         Customer Feedback Smoking Status Exercise Frequency Property Type  \
# 372605            Average             No             Weekly     Apartment
# 551204               Poor             No             Weekly     Apartment
# 240320               Poor             No            Monthly         House
# 1047361              Poor            Yes             Rarely         Condo
# 555362               Poor            Yes             Weekly     Apartment
# ...                   ...            ...                ...           ...
# 110268               Good             No             Rarely     Apartment
# 259178               Poor             No              Daily         House
# 131932            Average            Yes              Daily         Condo
# 671155               Good            Yes            Monthly         Condo
# 121958               Poor            Yes            Monthly     Apartment
#
#          Previous Claims  Policy Start Date  Premium Amount
# 372605               0.0           20200210          2742.0
# 551204               0.0           20201016          1347.0
# 240320          348080.0           20210102          2196.0
# 1047361         260033.0           20220511           684.0
# 555362          260033.0           20200728          1714.0
# ...                  ...                ...             ...
# 110268          133240.0           20201008           538.0
# 259178               0.0           20220115           819.0
# 131932               0.0           20230930           403.0
# 671155               0.0           20191011           542.0
# 121958          328995.0           20220125          2619.0
#
# [1200000 rows x 20 columns]
